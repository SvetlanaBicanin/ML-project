# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.13.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, numpy, opt-einsum, packaging, protobuf, setuptools, six, tensorboard, tensorflow-estimator, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by: dopamine-rl

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import shutil
import random

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Flatten, Input
from tensorflow.keras.optimizers import Adam
from PIL import Image
from numpy.random import seed
from sklearn.utils import class_weight

# %%
#ucitavanje podataka iz npy fajla

np.load.__defaults__=(None, True, True, 'ASCII')
X0 = np.load('drive/MyDrive/collection/data0.npy')
np.load.__defaults__=(None, False, True, 'ASCII')

# %%
np.load.__defaults__=(None, True, True, 'ASCII')
X1 = np.load('drive/MyDrive/collection/data1.npy')
np.load.__defaults__=(None, False, True, 'ASCII')

# %%
# format fotografija
img = X0[0]
print("Shape of image")
print(img.shape)
channel = 3
# Out:
# Shape of image
# (50, 50, 3)

# %%
print("Broj podataka sa pozitivnim IDC-om ", len(X1))
print("Broj podataka sa negativnim IDC-om ", len(X0))
print("Ukupan broj podataka ", len(X0)+len(X1))
# Out:
# Broj podataka sa pozitivnim IDC-om  5717
# Broj podataka sa negativnim IDC-om  18890
# Ukupan broj podataka  24607

# %%
print(X1.shape)
print(X0.shape)
# Out:
# (5717, 50, 50, 3)
# (18890, 50, 50, 3)

# %%
# pravimo i y0 i y1 na osnovu broja instanci jedne i druge klase
y0 = np.zeros(shape=(len(X0),1))
y1 = np.ones(shape=(len(X1),1))

# %%
#odvojicemo 50 % podataka za train, 20% za validaciju i 30% za test i iz skupa X0 i iz skupa X1
size_of_X0_train = int(len(X0) * 0.5)
size_of_X0_val = int(len(X0) * 0.2)


X0_train = X0[:size_of_X0_train]
X0_val = X0[size_of_X0_train : (size_of_X0_train+size_of_X0_val)]
X0_test = X0[(size_of_X0_train+size_of_X0_val) : ]

y0_train =y0[:size_of_X0_train]
y0_val = y0[size_of_X0_train : (size_of_X0_train+size_of_X0_val)]
y0_test = y0[(size_of_X0_train+size_of_X0_val) : ]

# %%
size_of_X1_train = int(len(X1) * 0.5)
size_of_X1_val = int(len(X1) * 0.2)

X1_train = X1[:size_of_X1_train]
X1_val = X1[size_of_X1_train : (size_of_X1_train+size_of_X1_val)]
X1_test = X1[(size_of_X1_train+size_of_X1_val) : ]

y1_train = y1[:size_of_X1_train]
y1_val = y1[size_of_X1_train : (size_of_X1_train+size_of_X1_val)]
y1_test = y1[(size_of_X1_train+size_of_X1_val) : ]

# %%
# sada cemo podeljene podatke po skupovima, objediniti po klasama, da bi imali skupove train test i val sa podacima iz obe klase
X_train = np.concatenate((X0_train, X1_train))
X_test =  np.concatenate((X0_test, X1_test))
X_val =  np.concatenate((X0_val, X1_val))
print(len(X_train)+len(X_test)+len(X_val))
print(len(X_train))
# Out:
# 24607
# 12303

# %%
# slicno radimo i za y
y_train = np.concatenate((y0_train, y1_train))
y_test =  np.concatenate((y0_test, y1_test))
y_val =  np.concatenate((y0_val, y1_val))
print(len(y_train)+len(y_test)+len(y_val))
# Out:
# 24607

# %%
#normalizacija - svodimo vrednosti pojedicnacnih piksela na vrednost iz intervala [0, 1]
X_train_norm = X_train/255
X_test_norm = X_test/255
X_val_norm = X_val/255

# %%
#iscrtavanje i analiza nekih podataka
# izmesacemo podatke pre nego sto ih budemo iscrtali da bi videli primere iz obe klase
perm_array = np.arange(len(X_train_norm))
np.random.shuffle(perm_array)
X_train_image_example = X_train_norm[perm_array]
y_train_image_example = y_train[perm_array]

i=0
for image in X_train_image_example[:9]:
        plt.subplot(3, 3, i+1)
        plt.imshow(image)
        plt.title(label=f"class: %s" % str(y_train_image_example[i]), color="purple")
        plt.axis('off')
        i+=1

# %%
# odnos pozitivno klasifikovanih i negativno klasifikovanih slika
plt.title('odnos podataka sa pozitivnim IDC-om i sa negativnim IDC-om')
plt.bar([0, 1], [len(X0), len(X1)])
plt.xticks([0, 1])
plt.plot()
# mozemo zakljuciti da su podaci neizbalansirani,
# iz tog razloga iskoristicemo jednu od metoda koje resavaju ovaj problem,
# koristicemo metod ansambla - bagging (prosta agregacija)
# metod podrazumeva obucavanje veceg broja modela  (u nasem slucaju imacemo 3 modela posto je takav odnos
# podataka razlicitih klasa)
# snaga ovakvog modela pociva na ideji da ce se prilikom agregacije greske koje modeli nezavisno prave ponistiti
# U nasem slucaju imamo 5717 instanci manjinske klase i 18890 instanci većinske klase, možemo napraviti 3
# skupa podataka od vecinske klase, sudeci po njihovom odnosu. Na svakom od ovih skupova se može naučiti
# poseban model, a kao konačna ocena se može iskoristiti princip većinskog glasanja za odlučivanje o finalnom obeležju nove instance.
# Out:
# []

# %%
# posto ne mozemo koristiti ugradjenu klasu za Bagging jer kao bazni model ne podrzava model CNN,
# ovako nesto cemo uraditi pesaka korak po korak
# iz tog razloga nam je  potrebno da sami podelimo X_train na 3 priblizno obimna skupa

print(f"Skup train podataka je velicine: %d" % len(X_train_norm))
print(f"Odnos klasa je %s "% str(len(X0_train)/len(X1_train)))

# njihov odnos je lepo rasporedjen kao i kod celokupnog skupa podataka ~~ 3,3
# iz tog razloga odlucili smo se da imamo 3 modela
# Out:
# Skup train podataka je velicine: 12303
# Odnos klasa je 3.3047585724282715

# %%
# 12303/3 ~~ 4000
# kao prvi train skup uzecemo 4000 podataka, kao drugi isto 4000, a kao treci cemo uzeti ostatak od 4303
# pre toga cemo ponovo izmesati podatke
perm_array = np.arange(len(X_train_norm))
np.random.seed(9)
np.random.shuffle(perm_array)
X_train = X_train_norm[perm_array]
y_train = y_train[perm_array]

X_train1 = X_train[:4000]
X_train2 = X_train[4000:8000]
X_train3 = X_train[8000:]

y_train1 = y_train[:4000]
y_train2 = y_train[4000:8000]
y_train3 = y_train[8000:]

print(len(X_train1))
print(len(X_train2))
print(len(X_train3))
print(len(y_train1))
print(len(y_train2))
print(len(y_train3))
# Out:
# 4000
# 4000
# 4303
# 4000
# 4000
# 4303

# %%
#promesacemo sada i validacioni i test skup
perm_array = np.arange(len(X_val_norm))
np.random.seed(9)
np.random.shuffle(perm_array)
X_val_shuffle = X_val_norm[perm_array]
y_val_shuffle = y_val[perm_array]

perm_array = np.arange(len(X_test_norm))
np.random.seed(9)

np.random.shuffle(perm_array)
X_test_shuffle = X_test_norm[perm_array]
y_test_shuffle = y_test[perm_array]

# %%
batch_size = 128
epochs = 30

# %%
# ovaj model cemo koristiti kod Bagging metode za resavanje nebalansiranosti
def defOfModel(input_shape, X_train, y_train, batch_size, ep=30):
  model = Sequential ([
    Input(shape = input_shape),
    Conv2D(filters = 32, kernel_size = (3, 3), strides = (2, 2), padding = 'same', activation = 'relu'),
    Conv2D(filters = 32, kernel_size = (3, 3), strides = (2, 2), padding = 'same', activation = 'relu'),
    MaxPooling2D(pool_size = (2, 2)),
    Dropout(0.25),
    Conv2D(filters = 64, kernel_size = (3, 3), strides = (2, 2), padding = 'same', activation = 'relu'),
    Conv2D(filters = 64, kernel_size = (3, 3), strides = (2, 2), padding = 'same', activation = 'relu'),
    MaxPooling2D(pool_size = (2, 2)),
    Dropout(0.25),
    Flatten(),
    Dense(128, activation = 'relu'),
    Dense(512, activation = 'relu'),
    Dropout(0.3),
    Dense(1, activation = 'sigmoid')
])
  model.summary()
  model.compile(loss = 'binary_crossentropy', optimizer = Adam(learning_rate=0.0002), metrics = ['accuracy'])

  batch_size = 128
  history = model.fit(X_train, y_train,
                      validation_split=0.2,
                      batch_size=batch_size,
                      epochs=ep,
                      verbose=1)
  return model, history

# %%
# ovaj model ce koristiti tezinu instanci da bi resio problem nebalansiranosti
def defOfModelWithClassWeight(input_shape, X_train, y_train, batch_size, ep=30):
  model = Sequential ([
    Input(shape = input_shape),
    Conv2D(filters = 32, kernel_size = (3, 3), strides = (2, 2), padding = 'same', activation = 'relu'),
    Conv2D(filters = 32, kernel_size = (3, 3), strides = (2, 2), padding = 'same', activation = 'relu'),
    MaxPooling2D(pool_size = (2, 2)),
    Dropout(0.25),
    Conv2D(filters = 64, kernel_size = (3, 3), strides = (2, 2), padding = 'same', activation = 'relu'),
    Conv2D(filters = 64, kernel_size = (3, 3), strides = (2, 2), padding = 'same', activation = 'relu'),
    MaxPooling2D(pool_size = (2, 2)),
    Dropout(0.25),
    Flatten(),
    Dense(128, activation = 'relu'),
    Dense(512, activation = 'relu'),
    Dropout(0.3),
    Dense(1, activation = 'sigmoid')
])
  model.summary()
  model.compile(loss = 'binary_crossentropy', optimizer = Adam(learning_rate=0.0002), metrics = ['accuracy'], weighted_metrics=['accuracy'])

  batch_size = 128
  sample_weights = class_weight.compute_sample_weight(class_weight = 'balanced',
                                                  y = y_train)

  history = model.fit(X_train, y_train,
                      validation_split=0.2,
                      batch_size=batch_size,
                      epochs=ep,
                      verbose=1, sample_weight=sample_weights)
  return model, history

# %%
# iscrtavanje grafika za metrike loss i accuracy po epohama
def graphOfLossAndAccuracy(history):
  plt.figure(figsize=(10, 4))

  plt.subplot(1, 2, 1)
  plt.title('Loss')
  plt.plot(np.arange(0, epochs), history.history['loss'], label='train')
  plt.plot(np.arange(0, epochs), history.history['val_loss'], label='val')
  plt.legend(loc='best')
  #plt.ylim(0,1)

  plt.subplot(1, 2, 2)
  plt.title('Accuracy')
  plt.plot(np.arange(0, epochs), history.history['accuracy'], label='train')
  plt.plot(np.arange(0, epochs), history.history['val_accuracy'], label='val')
  plt.legend(loc='best')
  #plt.ylim(0,1)

  plt.show()

# %%
def modelEvaluate(model, X_test, y_test):
  score = model.evaluate(X_test, y_test, verbose=0)
  print('Test loss:', score[0])
  print('Test accuracy:', score[1])
  return (score[0], score[1])

# %%
model1, hist1 = defOfModel(img.shape, X_train1, y_train1, batch_size, epochs)
model2, hist2 = defOfModel(img.shape, X_train2, y_train2, batch_size, epochs)
model3, hist3 = defOfModel(img.shape, X_train3, y_train3, batch_size, epochs)
model, hist = defOfModelWithClassWeight(img.shape, X_train, y_train, batch_size, epochs)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 25, 25, 32)        896
#
#  conv2d_9 (Conv2D)           (None, 13, 13, 32)        9248
#
#  max_pooling2d_4 (MaxPoolin  (None, 6, 6, 32)          0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 6, 6, 32)          0
#
#  conv2d_10 (Conv2D)          (None, 3, 3,
30
# 25/25 [==============================] - 4s 153ms/step - loss: 0.3828 - accuracy: 0.8419 - val_loss: 0.3878 - val_accuracy: 0.8263
# Epoch 18/30
# 25/25 [==============================] - 2s 96ms/step - loss: 0.3772 - accuracy: 0.8462 - val_loss: 0.4257 - val_accuracy: 0.8200
# Epoch 19/30
# 25/25 [==============================] - 4s 173ms/step - loss: 0.3904 - accuracy: 0.8419 - val_loss: 0.3969 - val_accuracy: 0.8275
# Epoch 20/30
# 25/25 [==============================] - 6s 229ms/step - loss: 0.3789 - accuracy: 0.8416 - val_loss: 0.3892 - val_accuracy: 0.8288
# Epoch 21/30
# 25/25 [==============================] - 5s 217ms/step - loss: 0.3749 - accuracy: 0.8481 - val_loss: 0.4157 - val_accuracy: 0.8250
# Epoch 22/30
# 25/25 [==============================] - 3s 127ms/step - loss: 0.3750 - accuracy: 0.8441 - val_loss: 0.4172 - val_accuracy: 0.8188
# Epoch 23/30
# 25/25 [==============================] - 6s 252ms/step - loss: 0.3725 - accuracy: 0.8441 - val_loss: 0.3931 - val_accuracy: 0.8325
# Epoch 24/30
# 25/25 [==============================] - 6s 233ms/step - loss: 0.3604 - accuracy: 0.8509 - val_loss: 0.3773 - val_accuracy: 0.8425
# Epoch 25/30
# 25/25 [==============================] - 6s 232ms/step - loss: 0.3577 - accuracy: 0.8597 - val_loss: 0.3821 - val_accuracy: 0.8363
# Epoch 26/30
# 25/25 [==============================] - 4s 160ms/step - loss: 0.3584 - accuracy: 0.8519 - val_loss: 0.3710 - val_accuracy: 0.8375
# Epoch 27/30
# 25/25 [==============================] - 3s 103ms/step - loss: 0.3516 - accuracy: 0.8584 - val_loss: 0.3769 - val_accuracy: 0.8363
# Epoch 28/30
# 25/25 [==============================] - 2s 99ms/step - loss: 0.3520 - accuracy: 0.8541 - val_loss: 0.3702 - val_accuracy: 0.8425
# Epoch 29/30
# 25/25 [==============================] - 2s 99ms/step - loss: 0.3515 - accuracy: 0.8525 - val_loss: 0.3846 - val_accuracy: 0.8313
# Epoch 30/30
# 25/25 [==============================] - 2s 91ms/step - loss: 0.3518 - accuracy: 0.8528 - val_loss: 0.3852 - val_accuracy: 0.8288
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 25, 25, 32)        896
#
#  conv2d_13 (Conv2D)          (None, 13, 13, 32)        9248
#
#  max_pooling2d_6 (MaxPoolin  (None, 6, 6, 32)          0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 6, 6, 32)          0
#
#  conv2d_14 (Conv2D)          (None, 3, 3, 64)          18496
#
#  conv2d_15 (Conv2D)          (None, 2, 2, 64)          36928
#
#  max_pooling2d_7 (MaxPoolin  (None, 1, 1, 64)          0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 1, 1, 64)          0
#
#  flatten_3 (Flatten)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 128)               8320
#
#  dense_10 (Dense)            (None, 512)               66048
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_11 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 140449 (548.63 KB)
# Trainable params: 140449 (548.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 25/25 [==============================] - 8s 187ms/step - loss: 0.6089 - accuracy: 0.7528 - val_loss: 0.4940 - val_accuracy: 0.7900
# Epoch 2/30
# 25/25 [==============================] - 6s 228ms/step - loss: 0.5233 - accuracy: 0.7672 - val_loss: 0.4966 - val_accuracy: 0.7900
# Epoch 3/30
# 25/25 [==============================] - 5s 187ms/step - loss: 0.5177 - accuracy: 0.7672 - val_loss: 0.4993 - val_accuracy: 0.7900
# Epoch 4/30
# 25/25 [==============================] - 4s 153ms/step - loss: 0.5170 - accuracy: 0.7672 - val_loss: 0.4978 - val_accuracy: 0.7900
# Epoch 5/30
# 25/25 [==============================] - 4s 156ms/step - loss: 0.5094 - accuracy: 0.7672 - val_loss: 0.4841 - val_accuracy: 0.7900
# Epoch 6/30
# 25/25 [==============================] - 4s 149ms/step - loss: 0
# Epoch 27/30
# 25/25 [==============================] - 3s 126ms/step - loss: 0.3659 - accuracy: 0.8581 - val_loss: 0.4037 - val_accuracy: 0.8325
# Epoch 28/30
# 25/25 [==============================] - 4s 149ms/step - loss: 0.3619 - accuracy: 0.8516 - val_loss: 0.4224 - val_accuracy: 0.8188
# Epoch 29/30
# 25/25 [==============================] - 2s 97ms/step - loss: 0.3496 - accuracy: 0.8597 - val_loss: 0.3977 - val_accuracy: 0.8425
# Epoch 30/30
# 25/25 [==============================] - 2s 97ms/step - loss: 0.3528 - accuracy: 0.8537 - val_loss: 0.3928 - val_accuracy: 0.8450
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 25, 25, 32)        896
#
#  conv2d_17 (Conv2D)          (None, 13, 13, 32)        9248
#
#  max_pooling2d_8 (MaxPoolin  (None, 6, 6, 32)          0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 6, 6, 32)          0
#
#  conv2d_18 (Conv2D)          (None, 3, 3, 64)          18496
#
#  conv2d_19 (Conv2D)          (None, 2, 2, 64)          36928
#
#  max_pooling2d_9 (MaxPoolin  (None, 1, 1, 64)          0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 1, 1, 64)          0
#
#  flatten_4 (Flatten)         (None, 64)                0
#
#  dense_12 (Dense)            (None, 128)               8320
#
#  dense_13 (Dense)            (None, 512)               66048
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  dense_14 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 140449 (548.63 KB)
# Trainable params: 140449 (548.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 27/27 [==============================] - 4s 106ms/step - loss: 0.5914 - accuracy: 0.7673 - val_loss: 0.5334 - val_accuracy: 0.7596
# Epoch 2/30
# 27/27 [==============================] - 4s 167ms/step - loss: 0.5104 - accuracy: 0.7772 - val_loss: 0.5217 - val_accuracy: 0.7596
# Epoch 3/30
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5043 - accuracy: 0.7772 - val_loss: 0.5211 - val_accuracy: 0.7596
# Epoch 4/30
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5037 - accuracy: 0.7772 - val_loss: 0.5153 - val_accuracy: 0.7596
# Epoch 5/30
# 27/27 [==============================] - 2s 90ms/step - loss: 0.4976 - accuracy: 0.7772 - val_loss: 0.5121 - val_accuracy: 0.7596
# Epoch 6/30
# 27/27 [==============================] - 3s 95ms/step - loss: 0.4938 - accuracy: 0.7772 - val_loss: 0.5049 - val_accuracy: 0.7596
# Epoch 7/30
# 27/27 [==============================] - 4s 156ms/step - loss: 0.4812 - accuracy: 0.7772 - val_loss: 0.4876 - val_accuracy: 0.7596
# Epoch 8/30
# 27/27 [==============================] - 3s 106ms/step - loss: 0.4697 - accuracy: 0.7772 - val_loss: 0.4762 - val_accuracy: 0.7596
# Epoch 9/30
# 27/27 [==============================] - 3s 106ms/step - loss: 0.4489 - accuracy: 0.7783 - val_loss: 0.4458 - val_accuracy: 0.7712
# Epoch 10/30
# 27/27 [==============================] - 3s 98ms/step - loss: 0.4273 - accuracy: 0.7949 - val_loss: 0.4184 - val_accuracy: 0.8153
# Epoch 11/30
# 27/27 [==============================] - 4s 148ms/step - loss: 0.4083 - accuracy: 0.8216 - val_loss: 0.4157 - val_accuracy: 0.8188
# Epoch 12/30
# 27/27 [==============================] - 5s 181ms/step - loss: 0.3964 - accuracy: 0.8283 - val_loss: 0.4001 - val_accuracy: 0.8362
# Epoch 13/30
# 27/27 [==============================] - 3s 97ms/step - loss: 0.3941 - accuracy: 0.8338 - val_loss: 0.3830 - val_accuracy: 0.8537
# Epoch 14/30
# 27/27 [==============================] - 3s 96ms/step - loss: 0.3768 - accuracy: 0.8495 - val_loss: 0.3739 - val_accuracy: 0.8537
# Epoch 15/30
# 27/27 [==============================] - 3s 95ms/step - loss: 0.3883 - accuracy: 0.8399 - val_loss: 0.3748 - val_accuracy: 0.8502
# Epoch 16/30
# 27/27 [==============================] - 3s 94ms/step - loss: 0.3746 - accuracy: 0.8457 - val_loss: 0.3756 - val_accuracy: 0.8490
# Epoch 17/30
# 27/27 [==============================] - 4s 162ms/step - loss: 0.3678 - accuracy: 0.8510 - val_loss: 0.3720 - val_accuracy: 0.8513
# Epoch 18/30
# 27/27 [==============================] - 3s 101ms/step - loss: 0.3828 - accuracy: 0.8434 - val_loss: 0.3814 - val_accuracy: 0.8571
# Epoch 19/30
# 27/27 [==============================] - 2s 90ms/step - loss: 0.3646 - accuracy: 0.8550 - val_loss: 0.3610 - val_accuracy: 0.8571
# Epoch 20/30
# 27/27 [==============================] - 2s 91ms/step - loss: 0.3642 - accuracy: 0.8524 - val_loss: 0.3649 - val_accuracy: 0.8560
# Epoch 21/30
# 27/27 [==============================] - 2s 90ms/step - loss: 0.3652 - accuracy: 0.8524 - val_loss: 0.3728 - val_accuracy: 0.8513
# Epoch 22/30
# 27/27 [==============================] - 4s 148ms/step - loss: 0.3573 - accuracy: 0.8556 - val_loss: 0.3615 - val_accuracy: 0.8571
# Epoch 23/30
# 27/27 [==============================] - 3s 118ms/step - loss: 0.3538 - accuracy: 0.8542 - val_loss: 0.3576 - val_accuracy: 0.8571
# Epoch 24/30
# 27/27 [==============================] - 3s 96ms/step - loss: 0.3582 - accuracy: 0.8536 - val_loss: 0.3675 - val_accuracy: 0.8502
# Epoch 25/30
# 27/27 [==============================] - 3s 96ms/step - loss: 0.3537 - accuracy: 0.8594 - val_loss: 0.3543 - val_accuracy: 0.8583
# Epoch 26/30
# 27/27 [==============================] - 3s 96ms/step - loss: 0.3487 - accuracy: 0.8597 - val_loss: 0.3641 - val_accuracy: 0.8583
# Epoch 27/30
# 27/27 [==============================] - 4s 143ms/step - loss: 0.3544 - accuracy: 0.8585 - val_loss: 0.3554 - val_accuracy: 0.8583
# Epoch 28/30
# 27/27 [==============================] - 3s 123ms/step - loss: 0.3496 - accuracy: 0.8623 - val_loss: 0.3618 - val_accuracy: 0.8513
# Epoch 29/30
# 27/27 [==============================] - 3s 97ms/step - loss: 0.3526 - accuracy: 0.8568 - val_loss: 0.3520 - val_accuracy: 0.8548
# Epoch 30/30
# 27/27 [==============================] - 2s 90ms/step - loss: 0.3508 - accuracy: 0.8579 - val_loss: 0.3571 - val_accuracy: 0.8490
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 25, 25, 32)        896
#
#  conv2d_21 (Conv2D)          (None, 13, 13, 32)        9248
#
#  max_pooling2d_10 (MaxPooli  (None, 6, 6, 32)          0
#  ng2D)
#
#  dropout_15 (Dropout)        (None, 6, 6, 32)          0
#
#  conv2d_22 (Conv2D)          (None, 3, 3, 64)          18496
#
#  conv2d_23 (Conv2D)          (None, 2, 2, 64)          36928
#
#  max_pooling2d_11 (MaxPooli  (None,
# Epoch 26/30
# 77/77 [==============================] - 9s 118ms/step - loss: 0.4026 - accuracy: 0.8343 - weighted_accuracy: 0.8258 - val_loss: 0.4128 - val_accuracy: 0.8139 - val_weighted_accuracy: 0.8168
# Epoch 27/30
# 77/77 [==============================] - 7s 91ms/step - loss: 0.3942 - accuracy: 0.8327 - weighted_accuracy: 0.8278 - val_loss: 0.4148 - val_accuracy: 0.8411 - val_weighted_accuracy: 0.8199
# Epoch 28/30
# 77/77 [==============================] - 9s 120ms/step - loss: 0.3918 - accuracy: 0.8382 - weighted_accuracy: 0.8311 - val_loss: 0.4281 - val_accuracy: 0.7903 - val_weighted_accuracy: 0.8149
# Epoch 29/30
# 77/77 [==============================] - 7s 93ms/step - loss: 0.3895 - accuracy: 0.8358 - weighted_accuracy: 0.8301 - val_loss: 0.4069 - val_accuracy: 0.8224 - val_weighted_accuracy: 0.8231
# Epoch 30/30
# 77/77 [==============================] - 9s 120ms/step - loss: 0.3837 - accuracy: 0.8408 - weighted_accuracy: 0.8347 - val_loss: 0.4384 - val_accuracy: 0.7631 - val_weighted_accuracy: 0.8006

# %%
graphOfLossAndAccuracy(hist1)
graphOfLossAndAccuracy(hist2)
graphOfLossAndAccuracy(hist3)
graphOfLossAndAccuracy(hist)

# %%
# Na osnovu grafika mozemo primetiti da za prvi i treci model vazi da nemaju velike razlike izmedju rezultata na validacionom i
# skupu za treniranje, pa samim tim nema ni preprilagodjavanja, nesto je gori odnos kod drugog modela gde vidimo da
# mozemo da smanjimo broj epoha na oko 10, dok poslednji model koji koristi tezine instacni takodje ne pokazuje preprilagodjavanje

# %%
loss1, acc1 = modelEvaluate(model1, X_val_shuffle, y_val_shuffle)
loss2, acc2 = modelEvaluate(model2, X_val_shuffle, y_val_shuffle)
loss3, acc3 = modelEvaluate(model3,X_val_shuffle, y_val_shuffle)
print("---------------------------------------------")
print("Prosek metrika ova tri modela: loss = ",((loss1+loss2+loss3)/3.0),' , accuracy = ', ((acc1+acc2+acc3)/3.0))
print("---------------------------------------------")
loss, acc = modelEvaluate(model, X_val_shuffle, y_val_shuffle)
# Out:
# Test loss: 0.3718293011188507
# Test accuracy: 0.8553139567375183
# Test loss: 0.3046412169933319
# Test accuracy: 0.883357048034668
# Test loss: 0.2979806661605835
# Test accuracy: 0.885185956954956
# ---------------------------------------------
# Prosek metrika ova tri modela: loss =  0.32481706142425537  , accuracy =  0.8746189872423807
# ---------------------------------------------
# Test loss: 0.5943711996078491
# Test accuracy: 0.751270055770874

# %%
# mozemo se i graficki uveriti da su modeli po preciznosti i gubitku vrlo slicni i da za krajnju evaluaciju na test skupu u ovom primeru
# mozemo koristiti bilo koji od modela
plt.title("Odnos accuracy i loss za ova dva modela")
plt.bar(['loss','accuracy'], [((loss1+loss2+loss3)/3.0), ((acc1+acc2+acc3)/3.0)], color ='maroon',
        width = 0.5, label='model-bagging')
plt.bar(['loss','accuracy'], [loss, acc], color ='blue',
        width = 0.3, label='model-class-weights')
plt.legend(loc='best')
plt.show()

# %%
# posto se bolje pokazao model koji koristi bagging, nega cemo koristiti za krajnju evaluaciju na test skupu

# %%
loss1, acc1 = modelEvaluate(model1, X_test_shuffle, y_test_shuffle)
loss2, acc2 = modelEvaluate(model2, X_test_shuffle, y_test_shuffle)
loss3, acc3 = modelEvaluate(model3, X_test_shuffle, y_test_shuffle)
#loss, acc = modelEvaluate(model, X_test_shuffle, y_test_shuffle)
# Out:
# Test loss: 0.4302651584148407
# Test accuracy: 0.8157930374145508
# Test loss: 0.42911937832832336
# Test accuracy: 0.8248679637908936
# Test loss: 0.4336499869823456
# Test accuracy: 0.8283895254135132

# %%
y_predicted1 = model1.predict(X_test_shuffle)
y_predicted2 = model2.predict(X_test_shuffle)
y_predicted3 = model3.predict(X_test_shuffle)
#y_predicted = model.predict(X_test_shuffle) # ovaj model necemo koristiti za evaluaciju na test skupu
# Out:
# 231/231 [==============================] - 3s 14ms/step
# 231/231 [==============================] - 2s 9ms/step
# 231/231 [==============================] - 2s 9ms/step

# %%
#brojanje glasova u slucaju modela sa bagging-om
arrays = np.array([y_predicted1,
          y_predicted2,
          y_predicted3])
y_pred = arrays.sum(axis=0)
y_pred = y_pred/3.0

# %%
# s obzirom da su dobijene predikciji date kao niz realnih brojeva u opsegu [0, 1], u slucaju da je vrednost < 0.3
# dodelicemo oznaku klase 0 inace oznaku klase 1, jer u slucaju da je model nesiguran bolje je reci da neko ima pozitivne IDC celije
# pa da se daljim ispitivanjem utvrdi suprotno
def inClasses(y_pred):
  i=0;
  res = []
  for el in y_pred:
    if el<0.3:
      res.append(0)
    else:
      res.append(1)
    i = i+1
  return res

# %%
y_predicted_in_classes = inClasses(y_pred)

# %%
y_pred_final = np.array(y_predicted_in_classes)

# %%
y_test_final = y_test_shuffle.reshape(-1)

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

confusion_matrix_bagging = confusion_matrix(y_test_final, y_pred_final)
#confusion_matrix = confusion_matrix(y_test_final, y_predicted_in_classes)

# %%
fig, ax = plt.subplots(figsize=(4,4))
display_matrix = ConfusionMatrixDisplay(confusion_matrix_bagging, display_labels=['0', '1'])
display_matrix.plot(ax=ax)

# %%
# mozemo primetiti da model ima znatno bolje rezultate za negativnu klasu, dok je za pozitivnu klasu dosta gresio
# narocito za FN, gde prediktuje da su celije sa pozitivnim IDC-om one sa negativnim (754), sto je veci greska u praksi
# nego pogresiti u suprotnom smislu  kod FP podataka

# %%
report = classification_report(y_test_final, y_pred_final)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.88      0.88      5667
#          1.0       0.60      0.56      0.58      1716
#
#     accuracy                           0.81      7383
#    macro avg       0.73      0.72      0.73      7383
# weighted avg       0.81      0.81      0.81      7383

# %%
# cuvanje svih modela
model1.save('models/bagging/model1.hdf5')
model2.save('models/bagging/model2.hdf5')
model3.save('models/bagging/model3.hdf5')

model.save('models/model_class_weights.hdf5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
